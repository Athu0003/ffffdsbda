# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import random as rd

# %%
ds_heart = pd.read_csv("heart.csv")
ds_heart
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
ds_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
ds_heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline

# %%
sns.lineplot(data=ds_heart[["Age","AHD"]], x="Age", y="AHD")
plt.show()

# %%
sns.barplot(data=ds_heart[["Age","ChestPain"]], x="ChestPain", y="Age")
# Out:
# <AxesSubplot:xlabel='ChestPain', ylabel='Age'>

# %%
x=ds_heart["ChestPain"].map({'typical':1,'asymptomatic':2,'nonanginal':3,'nontypical':4})
data=[]
for i in range(1,5):
  data.append(x.value_counts()[i])
print(data)
keys=['typical','asymptomatic','nonanginal','nontypical']
# Out:
# [23, 144, 86, 50]

# %%
palette_color = sns.color_palette('bright')

plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2031e840610>,
# ...
#  [Text(1.0688703878101182, 0.25983859232732825, 'typical'),
#   Text(-0.4275284961750052, 1.0135183199914735, 'asymptomatic'),
#   Text(-0.385139080738388, -1.0303726939743647, 'nonanginal'),
#   Text(0.9554664099235405, -0.5450540702607596, 'nontypical')],
#  [Text(0.5830202115327917, 0.14173014126945177, '8%'),
#   Text(-0.2331973615500028, 0.5528281745408037, '48%'),
#   Text(-0.21007586222093888, -0.5620214694405624, '28%'),
#   Text(0.5211634963219312, -0.29730222014223245, '17%')])

# %%
sns.histplot(data=ds_heart,x='Chol')
# Out:
# <AxesSubplot:xlabel='Chol', ylabel='Count'>

# %%
plt.scatter(x='Age',y='RestBP', data=ds_heart, c='g') 
plt.scatter(x='Age',y='Chol', data=ds_heart, c='r', marker='+') 
plt.xlabel('Age')
plt.ylabel('Chol and RestBP') 
plt.legend(title='scatter_plot') 
plt.show()

# %%
plt.figure() 
plt.legend(title='Scatter_plot')
sns.lmplot(x='Age', y='Chol', data=ds_heart, fit_reg=False)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(ds_heart["RestBP"],ds_heart["Age"])
plt.xlabel("Age")
plt.ylabel("AHD")
plt.show()

# %%
sns.barplot(data=ds_heart[["Age","ChestPain"]], x="ChestPain", y="Age")
plt.bar(ds_heart["ChestPain"], ds_heart["Age"])
 
plt.xlabel("ChestPain")
plt.ylabel("Age")
plt.title("Bar Graph")
plt.show()

# %%
x=ds_heart["ChestPain"].map({'typical':1,'asymptomatic':2,'nonanginal':3,'nontypical':4})
data=[]
for i in range(1,5):
  data.append(x.value_counts()[i])
print(data)
keys=['typical','asymptomatic','nonanginal','nontypical']
# Out:
# [23, 144, 86, 50]

# %%
plt.pie(data, labels = keys)
plt.show()

# %%
plt.hist(ds_heart['Chol'])
plt.show()

# %%
plt.scatter(ds_heart['Age'],ds_heart['Chol'])
plt.show()
